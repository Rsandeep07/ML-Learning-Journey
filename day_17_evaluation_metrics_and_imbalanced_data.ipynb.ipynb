# %% [markdown]
# # 📊 Evaluation Metrics & Baseline Models
#
# ## 🔹 Handling Imbalanced Data
# When one class dominates the dataset, ML models may become biased.
# Common techniques:
#
# ### ➤ Undersampling
# - Remove samples from majority class.
# - Risk: Loss of information.
#
# ### ➤ Oversampling
# - Generate synthetic samples for minority class.
# - Examples: **SMOTE, ADASYN**.
#
# ### ➤ Tomek Links (Cleaning Technique)
# - A pair of points from opposite classes that are **closest neighbors**.
# - They lie very close to the decision boundary.
# - We remove the **majority class** point to make boundary clearer.
#
# 👉 Applied only on **training data**.
#
# ---
#
# ## 🔹 Problem Types
#
# ### 🟢 Classification
# Target is **categorical**
# Example:
# `y = [M, F, M, F, M]`
#
# ### 🔵 Regression
# Target is **continuous**
# Example:
# `y = [23.5, 30, 24, 26.2]` (BMI values)
#
# ---
#
# ## 🔹 Baseline (Basic) Models
#
# Before using ML algorithms, build simple reference models:
#
# ### ➤ Regression → Mean Model
# Predict the average of target values:
# \[
# \hat{y} = \bar{y}_{train}
# \]
#
# If ML model performs better than mean model → useful model.
#
# ### ➤ Classification → Mode Model
# Predict the most frequent class:
# \[
# \hat{y} = mode(y_{train})
# \]
#
# If ML model beats mode model → useful model.
#
# ---
#
# ## 🔹 Why Baseline Models?
# They act as **benchmarks**.
# Any ML model should outperform them.
#
# ---
#
# ## 🔹 Confusion Matrix Terms
#
# | Term | Meaning |
# |------|---------|
# TP | True Positive (correct +ve)
# TN | True Negative (correct -ve)
# FP | False Positive (wrong +ve)
# FN | False Negative (wrong -ve)
#
# ---
#
# ## 🔹 Evaluation Metrics (Classification)
#
# ### ✅ Accuracy
# \[
# \frac{TP + TN}{TP + TN + FP + FN}
# \]
#
# ### 🎯 Precision
# Correct positive predictions out of all predicted positives:
# \[
# \frac{TP}{TP + FP}
# \]
#
# ### 🔁 Recall (Sensitivity)
# Correct positive predictions out of all actual positives:
# \[
# \frac{TP}{TP + FN}
# \]
#
# ### ⚖️ F1 Score
# Harmonic mean of Precision & Recall:
# \[
# \frac{2 \cdot P \cdot R}{P + R}
# \]
#
# ### 📈 ROC-AUC
# Trade-off between TPR and FPR.
#
# ---
#
# ## 🔹 Why Focus on Positive Class?
#
# Positive class usually represents:
# - Disease present (COVID +ve)
# - Spam email
# - Fraud transaction
#
# ➡️ Missing positives can be **costly**, so Recall & Precision matter more.
#
# ---
#
# ## 🔹 Examples
#
# ### 🦠 COVID Test
# +ve → infected
# -ve → not infected
#
# ### 📧 Spam Detection
# Spam → Positive
# Ham → Negative
#
# Goal: Catch spam even if few hams get flagged.
#
# ---
#
# ## 🔹 Regression Evaluation
#
# Compared against **Mean Model** using:
# - MAE
# - MSE
# - RMSE
# - R² Score
